# %%
from scipy.stats import binom

# %%
binom.cdf(910, 921, 1-0.001)
# Out:
# 4.1526252870100695e-09

# %%
binom.cdf(439, 942, 0.5)
# Out:
# 0.020024886651453078

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.plot(range(100), [binom.pmf(x, 94, 0.5) for x in range(100)])

# %%
import numpy as np

# %%
plt.plot(range(1000), [np.log10(binom.pmf(x, 940, 0.001)) for x in range(1000)])
plt.plot(range(1000), [np.log10(binom.pmf(x, 940, 0.5)) for x in range(1000)])
plt.axvline(100)
# Out:
# /home/rhlin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /home/rhlin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %%
plt.plot(range(1000), [binom.cdf(x, 942, 0.5) for x in range(1000)])

# %%
1 - binom.cdf(503, 942, 0.01)
# Out:
# 1.1102230246251565e-16

# %%
binom.cdf(0, 942, 0.5)
# Out:
# 2.689949238098904e-284

# %%
binom.cdf(46, 100, 0.5)
# Out:
# 0.2420592068036454

# %%
x = 1
(x>5) ^ (x <5)
# Out:
# True

# %%
(False) ^ (False)
# Out:
# False

# %%
binom.cdf(0, 29999997, 0.001)
# Out:
# 0.0

# %%
binom.cdf(265, 626, 0.5)
# Out:
# 7.124598455520779e-05

# %%
import pandas as pd

# %%
df = pd.read_csv("/local/storage/rhlin/ESP_7_output/cdf_log.txt", sep="\t", header = None) \
    .rename(columns={0: "ORF", 1: "Colony", 2: "Identifier", 3: "Expected Percentage", \
                     4: "cdf_mut", 5: "cdf_no_mut", 6: "cdf_scaled"})

# %%
positions = df["Identifier"].apply(lambda x: x.split("_")[1][1:-1])
df['pos'] = positions

# %%
df
# Out:
#        ORF Colony    Identifier  Expected Percentage     cdf_mut   cdf_no_mut  \
# 0       27      A      27_C480G             0.998950 -353.170040  -469.749009
# 1     8221      A    8221_G367A             0.498950 -110.753281  -799.171917
# 2     3078      A    3078_A412G             0.332283  -96.882217 -1596.191919
# 3     3078      A    3078_G206A             0.332283  -92.394122 -1642.730802
# 4     3078      A    3078_T296C             0.332283 -126.169871 -1425.568691
# ..     ...    ...           ...                  ...         ...          ...
# 321  10037      B  10037_T1139G             0.498874  -40.322301 -3812.713612
# 322  10063      B   10063_A497G             0.498874  -70.444362 -3617.739603
# 323   3966      B    3966_A788G             0.141731  -61.309112  -827.432519
# 324   3966      B    3966_T868G             0.141731  -42.129791  -562.810508
# 325   2659      B   2659_T2275C             0.498874  -56.806816 -3667.180992
#
#      cdf_scaled   pos
# ...

# %%
df_a = df[df["Colony"] == "A"]
df_a["ORF"] = df_a["ORF"].astype(str)
df_a["pos"] = df_a["pos"].astype(int)
df
# Out:
# /home/rhlin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/rhlin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        ORF Colony    Identifier  Expected Percentage     cdf_mut   cdf_no_mut  \
# 0       27      A      27_C480G             0.998950 -353.170040  -469.749009
# ...

# %%
# pd.merge(df1, df2, on = [col1, col2], how = "left")

# %%
readCounts = pd.read_csv("/local/storage/rhlin/ESP_7_output/ESP_7_A_trimmed_read_counts.txt", sep="\t", \
                        header=None).rename(columns={0: "ORF", 1: "pos", 2: "read counts"})
readCounts["pos"] = readCounts["pos"].apply(lambda x: x + 1)
readCounts["ORF"] = readCounts["ORF"].astype(str)
readCounts["pos"] = readCounts["pos"].astype(int)
readCounts
# Out:
#            ORF  pos                         read counts
# 0        55296  805  {'A': 0, 'T': 0, 'C': 163, 'G': 0}
# 1        55296  806  {'A': 0, 'T': 165, 'C': 0, 'G': 0}
# 2        55296  807  {'A': 167, 'T': 0, 'C': 0, 'G': 0}
# 3        55296  808  {'A': 0, 'T': 0, 'C': 0, 'G': 166}
# 4        55296  809  {'A': 0, 'T': 165, 'C': 1, 'G': 0}
# ...        ...  ...                                 ...
# 1188744   8190   50  {'A': 0, 'T': 0, 'C': 575, 'G': 0}
# 1188745   8190   51  {'A': 559, 'T': 0, 'C': 0, 'G': 0}
# 1188746   8190   52  {'A': 0, 'T': 0, 'C': 575, 'G': 0}
# 1188747   8190   53  {'A': 0, 'T': 0, 'C': 577, 'G': 0}
# 1188748   8190   54  {'A': 579, 'T': 0, 'C': 0, 'G': 1}
#
# [1188749 rows x 3 columns]

# %%
readCounts
# Out:
#            ORF  pos                         read counts
# 0        55296  805  {'A': 0, 'T': 0, 'C': 163, 'G': 0}
# 1        55296  806  {'A': 0, 'T': 165, 'C': 0, 'G': 0}
# 2        55296  807  {'A': 167, 'T': 0, 'C': 0, 'G': 0}
# 3        55296  808  {'A': 0, 'T': 0, 'C': 0, 'G': 166}
# 4        55296  809  {'A': 0, 'T': 165, 'C': 1, 'G': 0}
# ...        ...  ...                                 ...
# 1188744   8190   50  {'A': 0, 'T': 0, 'C': 575, 'G': 0}
# 1188745   8190   51  {'A': 559, 'T': 0, 'C': 0, 'G': 0}
# 1188746   8190   52  {'A': 0, 'T': 0, 'C': 575, 'G': 0}
# 1188747   8190   53  {'A': 0, 'T': 0, 'C': 577, 'G': 0}
# 1188748   8190   54  {'A': 579, 'T': 0, 'C': 0, 'G': 1}
#
# [1188749 rows x 3 columns]

# %%
df_merge = pd.merge(df_a, readCounts, on=["ORF", "pos"], how = "left")

# %%
df_merge
# Out:
#       ORF Colony    Identifier  Expected Percentage     cdf_mut   cdf_no_mut  \
# 0      27      A      27_C480G             0.998950 -353.170040  -469.749009
# 1    8221      A    8221_G367A             0.498950 -110.753281  -799.171917
# 2    3078      A    3078_A412G             0.332283  -96.882217 -1596.191919
# 3    3078      A    3078_G206A             0.332283  -92.394122 -1642.730802
# 4    3078      A    3078_T296C             0.332283 -126.169871 -1425.568691
# ..    ...    ...           ...                  ...         ...          ...
# 75  14312      A   14312_A703G             0.998950 -636.632620  -958.939311
# 76  12146      A  12146_G1037C             0.998950   -4.589854  -957.840485
# 77  55247      A   55247_T980C             0.998950   -4.317918 -1108.442749
# 78  10225      A    10225_C43A             0.498950 -164.705019  -842.013421
# 79   8180      A     8180_G94C             0.998950   -5.612054 -1939.520122
#
# ...

# %%
'''
27_C480G: agree
8221_G367A: disagree
3078_A412G: agree
3078_G206A: agree
3078_T296C: agree
14312_A703G: agree
'''
